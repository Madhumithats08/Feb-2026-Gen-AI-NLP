# %% [markdown]
# Task 1: Conceptual Understanding
# 1. Difference between "Love" and "love" in NLP
# "Love" and "love" are treated as different tokens in case-sensitive NLP systems. Lowercasing ensures both are treated as the same word.
#
# 2. What happens if stopwords are not removed?
# If stopwords are not removed, they increase noise in the dataset and reduce model performance because frequent words like "is", "the", and "and" dominate the text.
#
# 3. Two real-world scenarios where removing stopwords can be harmful
# Example 1: "I am not happy" Removing "not" changes sentiment meaning.
#
# Example 2: "To be or not to be" Stopwords are necessary to preserve sentence meaning.
#
# 4. Difference between stemming and lemmatization
# Stemming removes suffixes without considering grammar. Example: playing → play
#
# Lemmatization converts words to dictionary base form. Example: better → good

# %%
# Task 2: Import Required Libraries

import re
from collections import Counter

# %% [markdown]
# Task 3: Build Advanced Preprocessing Function

# %%
def preprocess_text(text):

    # Handle empty or invalid input
    if not isinstance(text, str) or text.strip() == "":
        return [], ""

    # Remove URLs
    text = re.sub(r"http\S+|www\S+", "", text)

    # Remove email-like patterns
    text = re.sub(r"\S+@\S+", "", text)

    # Remove numbers
    text = re.sub(r"\d+", "", text)

    # Normalize repeated characters (loooove → love)
    text = re.sub(r"(.)\1{2,}", r"\1", text)

    # Convert to lowercase
    text = text.lower()

    # Remove special characters
    text = re.sub(r"[^a-z\s]", "", text)

     # Remove extra spaces
    text = re.sub(r"\s+", " ", text).strip()

    # Tokenize text
    tokens = text.split()

    # Remove very short tokens except "no" and "not"
    tokens = [word for word in tokens if len(word) > 2 or word in ["no", "not"]]

    # Join tokens back into cleaned sentence
    clean_sentence = " ".join(tokens)

    return tokens, clean_sentence

# %% [markdown]
# Task 4: Stress Testing the Preprocessing Function

# %%
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OKayy OKay OKayy I got it",
    "Win $$$ now!!! Limited offer!",
    "I am not happy with that"
]

# %%
#PREPROCESSING
processed_results = []

for sentence in test_sentences:

    tokens, clean_sentence = preprocess_text(sentence)

    processed_results.append(tokens)

    print("Original:", sentence)
    print("Tokens:", tokens)
    print("Clean sentence:", clean_sentence)
    print("-" * 40)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Clean sentence: get free access now
# ----------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'loved', 'this', 'product']
# Clean sentence: absolutely loved this product
# ----------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Clean sentence: worst service ever
# ----------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Clean sentence: call
# ----------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Clean sentence: this the best course
# ----------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Clean sentence: visit now
# ----------------------------------------
# Original: Nooooo this is baaad!!!
# Tokens: ['no', 'this', 'bad']
# Clean sentence: no this bad
# ----------------------------------------
# Original: OKayy OKay OKayy I got it
# Tokens: ['okayy', 'okay', 'okayy', 'got']
# Clean sentence: okayy okay okayy got
# ----------------------------------------
# Original: Win $$$ now!!! Limited offer!
# Tokens: ['win', 'now', 'limited', 'offer']
# Clean sentence: win now limited offer
# ----------------------------------------
# Original: I am not happy with that
# Tokens: ['not', 'happy', 'with', 'that']
# Clean sentence: not happy with that
# ----------------------------------------

# %% [markdown]
# Task 5: Token Analytics

# %%
for tokens in processed_results:

    if len(tokens) == 0:
        continue

    total_tokens = len(tokens)
    unique_tokens = len(set(tokens))
    avg_token_length = sum(len(word) for word in tokens) / total_tokens

    print("Tokens:", tokens)
    print("Total tokens:", total_tokens)
    print("Unique tokens:", unique_tokens)
    print("Average token length:", avg_token_length)
    print("-" * 40)
# Out:
# Tokens: ['get', 'free', 'access', 'now']
# Total tokens: 4
# Unique tokens: 4
# Average token length: 4.0
# ----------------------------------------
# Tokens: ['absolutely', 'loved', 'this', 'product']
# Total tokens: 4
# Unique tokens: 4
# Average token length: 6.5
# ----------------------------------------
# Tokens: ['worst', 'service', 'ever']
# Total tokens: 3
# Unique tokens: 3
# Average token length: 5.333333333333333
# ----------------------------------------
# Tokens: ['call']
# Total tokens: 1
# Unique tokens: 1
# Average token length: 4.0
# ----------------------------------------
# Tokens: ['this', 'the', 'best', 'course']
# Total tokens: 4
# Unique tokens: 4
# Average token length: 4.25
# ----------------------------------------
# Tokens: ['visit', 'now']
# Total tokens: 2
# Unique tokens: 2
# Average token length: 4.0
# ----------------------------------------
# Tokens: ['no', 'this', 'bad']
# Total tokens: 3
# Unique tokens: 3
# Average token length: 3.0
# ----------------------------------------
# Tokens: ['okayy', 'okay', 'okayy', 'got']
# Total tokens: 4
# Unique tokens: 3
# Average token length: 4.25
# ----------------------------------------
# Tokens: ['win', 'now', 'limited', 'offer']
# Total tokens: 4
# Unique tokens: 4
# Average token length: 4.5
# ----------------------------------------
# Tokens: ['not', 'happy', 'with', 'that']
# Total tokens: 4
# Unique tokens: 4
# Average token length: 4.0
# ----------------------------------------

# %% [markdown]
# Task 6: Frequency Analysis

# %%
all_tokens = []

for tokens in processed_results:
    all_tokens.extend(tokens)

word_frequency = Counter(all_tokens)

print("Top 10 frequent words:")
print(word_frequency.most_common(10))

print("\nTop 5 least frequent words:")
print(word_frequency.most_common()[-5:])
# Out:
# Top 10 frequent words:
# [('now', 3), ('this', 3), ('okayy', 2), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1)]
#
# Top 5 least frequent words:
# [('offer', 1), ('not', 1), ('happy', 1), ('with', 1), ('that', 1)]

# %% [markdown]
# Task 7: Build Full NLP Pipeline

# %%
def full_pipeline(text_list):

    all_tokens = []
    clean_sentences = []

    for text in text_list:

        tokens, sentence = preprocess_text(text)

        all_tokens.extend(tokens)
        clean_sentences.append(sentence)

    return {
        "tokens": all_tokens,
        "clean_sentences": clean_sentences
    }
pipeline_result = full_pipeline(test_sentences)

print(pipeline_result)
# Out:
# {'tokens': ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'okayy', 'okay', 'okayy', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'that'], 'clean_sentences': ['get free access now', 'absolutely loved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'no this bad', 'okayy okay okayy got', 'win now limited offer', 'not happy with that']}

# %% [markdown]
# Task 8: Error Handling

# %%
error_test_cases = [
    "",
    "😂😂😂😂",
    "123456789"
]

for case in error_test_cases:

    tokens, clean_sentence = preprocess_text(case)

    print("Original:", case)
    print("Tokens:", tokens)
    print("Clean sentence:", clean_sentence)
    print("-" * 40)
# Out:
# Original:
# Tokens: []
# Clean sentence:
# ----------------------------------------
# Original: 😂😂😂😂
# Tokens: []
# Clean sentence:
# ----------------------------------------
# Original: 123456789
# Tokens: []
# Clean sentence:
# ----------------------------------------
